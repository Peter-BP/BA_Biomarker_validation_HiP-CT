# %% [markdown]
# ### Plotting histogram for vectortree

# %%
from plotting.histogram_plots import validate_vector_tree_config
validate_vector_tree_config(n_trees=25, max_generations=8, initial_radius=8, enable_tortuosity=True)

# %% [markdown]
# ### Plotting histogram for voxeltree

# %%
from plotting.histogram_plots import validate_skeletonized_pipeline
validate_skeletonized_pipeline(n_trees=10, max_generations=8, initial_radius=8, enable_tortuosity=True)

# %% [markdown]
# ### Plotting histogram for real tree
# Labels from https://github.com/cns-iu/hra-sennet-hoa-kaggle-2024
#
# Download and change PATH_TO_FILE to your directory

# %%
from plotting.histogram_plots import plot_real_data_biomarkers
PATH_TO_FILE = "C:/Users/Peter/Desktop/Bachelorprojekt/Data/blood-vessel-segmentation/train/kidney_2/labels"
plot_real_data_biomarkers(
    path_to_data=PATH_TO_FILE,
    voxel_size_um=1,
    scale=1.0,
    target_label_value=None,
    use_cache=True)

# %% [markdown]
# ### Plotting disruption over strength

# %%
from plotting.histogram_plots import *
df_seg, df_bif = run_diagnostic_experiment_in_memory(n_trees=5, plot_results=False)

plot_diagnostic_dashboard(df_seg, df_bif)
